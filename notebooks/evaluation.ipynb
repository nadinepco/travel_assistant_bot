# %%
from langchain.storage import InMemoryByteStore
from langchain_chroma import Chroma
from langchain_openai import OpenAIEmbeddings
from langchain.retrievers.multi_vector import MultiVectorRetriever
from typing import Iterable
from langchain_core.documents import Document
import json

# %% [markdown]
# ## Read chunked dataset and raw dataset

# %%
def load_docs_from_jsonl(file_path)->Iterable[Document]:
    array = []
    with open(file_path, 'r') as jsonl_file:
        for line in jsonl_file:
            data = json.loads(line)
            obj = Document(**data)
            array.append(obj)
    return array

chunked_documents=load_docs_from_jsonl('../data/processed_dataset/chunked_documents.jsonl')
raw_documents=load_docs_from_jsonl('../data/processed_dataset/raw_documents.jsonl')

# %%
# check data contents
chunked_documents[0:5]
# Out:
# [Document(metadata={'title': 'Booking Confirmation and Ticket Instructions', 'location': 'Tromsø, Norway', 'type': 'activity', 'source': 'data/aurora_borealis_tour.pdf', 'doc_id': 0, 'chunk_id': 0}, page_content='Booking Confirmation and Ticket Instructions:Thanks for your order, Nadine. For easy access to your ticket and to be able to manage your booking on the go, download our app. November 30, 2023, at 6:30 PM From Tromsø: Aurora Borealis Tour 4 Adults (Age 0 - 99) • English • 6 hours € 555. See activity details. Get the GetYourGuide app to access your activity. Access your activity with the GetYourGuide app. Just open your tickets in the app and you’ll be ready to go.'),
#  Document(metadata={'title': 'Important Information and Meeting Instructions', 'location': 'Tromsø, Norway', 'type': 'activity', 'source': 'data/aurora_borealis_tour.pdf', 'doc_id': 0, 'chunk_id': 1}, page_content="Important Information and Meeting Instructions:Where to go: Fredrik Langes gate 2, 9008 Tromsø, Norway. Meet your guide outside the Scandic Ishavshotel. When to arrive: 6:20 PM - Arrive at the meeting point 10 minutes before your chosen time so you don't lose your time slot. Where your activity ends: Your activity will end at the same place it began."),
#  Document(metadata={'title': 'Tour Duration and Northern Lights Sightings', 'location': 'Tromsø, Norway', 'type': 'activity', 'source': 'data/aurora_borealis_tour.pdf', 'doc_id': 0, 'chunk_id': 2}, page_content="Tour Duration and Northern Lights Sightings:Important information: Know before you go. Keep in mind Northern Lights sightings are not guaranteed. A refund will not be offered if these aren't visible on the day of your tour. Drop-off is only available at hotels in the center of Tromsø, not at Airbnb or other accommodation. Our tour duration has an estimated time of 6 hours. It can change from 5-8 hours depending on driving distance, weather, and aurora activity."),
#  Document(metadata={'title': 'Cancellation Policy and Contact Information', 'location': 'Tromsø, Norway', 'type': 'activity', 'source': 'data/aurora_borealis_tour.pdf', 'doc_id': 0, 'chunk_id': 3}, page_content='Cancellation Policy and Contact Information:Cancellation policy: Cancel before 6:30 PM on November 29th for a full refund. Manage your booking: Your activity provider is Arctic Breeze AS. Contact them if you have any questions about your activity. +47 90 98 09 19. Email. Booking reference RM6K4FLS. PIN aBCdEg1. You paid € 555. View and save your receipt by downloading the PDF version below. This is not your ticket. See above for details of how to access your activity. Download receipt. Find the Terms & Conditions for your booking attached to this email, including information about your right of withdrawal.'),
#  Document(metadata={'title': 'Additional Support and Contact Information', 'location': 'Tromsø, Norway', 'type': 'activity', 'source': 'data/aurora_borealis_tour.pdf', 'doc_id': 0, 'chunk_id': 4}, page_content='Additional Support and Contact Information:Continue your trip in our app. Access your tickets offline. Get support in just 1 minute. Get essential updates on the go. We’re here to help. Questions about your activity? For questions about your meeting point, pickup service, or other queries about what happens on the day, contact your activity provider (see above). Questions about your booking? For questions about rescheduling, cancellations, refunds, or other matters regarding your booking, check out our Help Center. GetYourGuide Deutschland GmbH, Sonnenburger Strasse 73, 10437 Berlin, Germany. Managing directors: Johannes Reck, Tao Tao, Nils Chrestin. Registered at District Court of Charlottenburg HRB 132059 B, VAT ID No. DE276456081. For more information, please view our Privacy Policy.')]

# %%
raw_documents[0:5]
# Out:
# [Document(metadata={'source': 'data/aurora_borealis_tour.pdf', 'doc_id': 0}, page_content="Fwd: Booking RM6K4FLS confirmed | Ticket instructions\n1 message\nFrom: GetYourGuide\n To: NadineTue, Sep 12, 2023 at 4:54 PM\nThanks for your order,\nNadine\nFor easy access to your ticket and to be able to\nmanage your booking on the go, download our\napp.\nNovember 30, 2023 at 6:30 PM\nFrom Tromsø: Aurora\nBorealis Tour\n4 Adults (Age 0 - 99) • English • 6 hours\n€ 555\nSee activity details\nGet the GetYourGuide app to access your\nactivity\nAccess your activity with the GetYourGuide app. Just\nopen your tickets in the app and you’ll be ready to go.What to do on the day\nWhere to go Fredrik Langes gate 2, 9008 Tromsø,\nNorway Meet your guide outside the Scandic Ishavshotel.\nWhen to arrive\n6:20 PM - Arrive at the meeting point 10 minutes before \nyour chosen time so you don't lose your time slot.\nWhere your activity ends\nYour activity will end at the same place it began.\nImportant information\nKnow before you go Keep in mind Northern Lights\nsightings are not guaranteed. A refund will not be offered\nif these aren't visible on the day of your tour Drop-off is\nonly available at hotels in the center of Tromsø, not at\nAirbnb or other accommodation Our tour duration has an\nestimated time of 6 hours. It can change from 5-8 hours.\nThis depend on driving distance, weather and aurora\nactivity.\nCancellation policy\nCancel before 6:30 PM on November 29th for a full\nrefund\nManage your booking\nYour activity provider is Arctic Breeze AS\nContact them if you have any questions about your\nactivity.+47 90 98 09 19 Email\nBooking reference RM6K4FLS\nPIN aBCdEg1\nYou paid € 555\nView and save your receipt by downloading the PDF version\nbelow. This is not your ticket. See above for details of how to\naccess your activity.\nDownload receipt\nFind the Terms & Conditions for your booking attached to\nthis email, including information about your right of\nwithdrawal.Continue your trip in\nour app\nAccess your tickets\noffline Get support in\njust 1 minute Get\nessential updates on\nthe goWe’re here to help\nQuestions about your activity?\nFor questions about your meeting point, pickup service,\nor other queries about what happens on the day, contact\nyour activity provider (see above).\nQuestions about your booking?\nFor questions about rescheduling, cancellations, refunds,\nor other matters regarding your booking, check out our\nHelp Center.\nGetYourGuide Deutschland GmbH, Sonnenburger Strasse 73, 10437 Berlin, Germany. Managing\ndirectors: Johannes Reck, Tao Tao, Nils Chrestin. Registered at District Court of Charlottenburg HRB\n132059 B, VAT ID No. DE276456081. For more information, please view our Privacy Policy."),
#  Document(metadata={'source': 'data/Tromso_Nov30_Dec4.pdf', 'doc_id': 1}, page_content="PRICE\n1 unit                                                                                                                                                                        € 910\n \nPrice                                                                              €910\n(for 2 guests)\nAdditional information\nPlease note that additional supplements (e.g. extra bed) are not added in this total. If you don't show up or cancel,\napplicable taxes may still be charged by the property. Please remember to read the Important information below, as this\nmay contain important details not mentioned here.\n Standard Double Room\nGuest name: Nadine / for max. 2 people. \nMeal Plan: There is no meal option with this room.\nShower • Toilet • Towels • Linen • Desk • Seating Area • Heating • Hairdryer • Toilet\npaper • Cable channels • Upper floors accessible by elevator\nBed Size(s):1 double bed (131-150 cm wide)Comfort Hotel Xpress Tromsø\nAddress: Grønnegata 35, 9008 Tromsø, Norway\n Hotel Policies\nGuest parking\nPrivate parking is possible on site (reservation is not\npossible) and costs € 20 per day.\nWiFi is available in all areas and is free of charge. Booking confirmation\nCONFIRMATION NUMBER:  3645.982.716\nPIN CODE: 9032\nCancellation policy: \nYou may cancel free of charge until 3 days before\narrival. If you cancel in\nthe 3 days before arrival, the\ncancellation fee will be the total price\nof the reservation. If you don't show\nup, the no-show fee will be the same\nas the cancellation fee.UNIT NIGHTS\n1/4CHECK-IN\n30\nNOVEMBER\nThursday\n 15:00 - 00:00 CHECK-OUT\n4\nDECEMBER\nMonday\nUntil 12:00"),
#  Document(metadata={'source': 'data/Flixbus_Berlin-Prague.pdf', 'doc_id': 2}, page_content='07.09.2024, 10:00 Uhr\nBerlin ZOB\n07.09.2024, 14:25 Uhr\nPrag Busbahnhof (ÚAN Florenc)1 Erwachsener\nGesamtpreisRechnung #mfb-3021922191\n11.03.2024 11:21Buchungsnummer: #3063184481\nLAND CZ USt\nDE*\nWERTGUTSCHEINMit Deiner Buchung wurden 1 Ticket generiert. Pro Person und Fahrt wird ein Ticket generiert.\nNETTO\n7,64 €\n--MWST.\n0 %\n--STEUER\n0,00 €\n--BRUTTO\n7,64 €\n17,35 €\n-16,67 €\n8,32 €\nBereits bezahlt per: KreditkarteLLM Zoomcamp\nPersonenbeförderung im Auftrag, in Verantwortung und auf Rechnung von FlixBus\nDACH GmbH, Karl-Liebknecht-Straße 33, D-10178 Berlin, USt-IdNr.:DE278362610\n(Unternehmer gemäß Paragraph 3(2) des Personenbeförderungsgesetzes (PBefG)),\nvermittelt durch Flix SE.Flix SE\nFriedenheimer Brücke\n16\nD-80639 MünchenGeschäftsführer:\nAndré Schwämmlein\nDaniel KraussAmtsgericht München\nHRB 274912\nUSt-ID-Nr. DE\n283764680*Berechtigt nicht zum\nVorsteuerabzug\nFür die Buchung der Tickets gelten die Allgemeinen Geschäfts- und Buchungsbedingungen der Flix SE. Diese finden Sie unter: https://www.flixbus.de/agb. Für die Beförderung gelten die Allgemeinen\nBeförderungsbedingungen des jeweiligen Beförderers. Diese finden Sie unter: https://www.flixbus.de/abb-auswahl. Wer ist Beförderer/Konzessionsinhaber („Beförderer“) meiner Verbindung? Den\nBeförderer finden Sie in der Rechnung. Seite 1Rechnungen für Deine Buchung'),
#  Document(metadata={'source': 'data/Dog_Sledding_Confirmation_Norway.pdf', 'doc_id': 3}, page_content='Booking Confirmation for Dog Sledding Adventure\nCustomer Name: Nadine\nBooking ID: BKD-56273\nDate of Booking: September 15, 2023\nTravel Agency: Nordic Adventures AS\nActivity Details:\nDate of Activity: December 3, 2023\nTime: 8:45 AM to 3:45 PM\nMeeting Point: Radisson Blu Hotel Tromsø (Outside the main entrance)\nWhat to Bring:\n- Wool socks\n- Warm hat and gloves\n- Sunglasses with UV protection\n- Water bottle and snacks\n- Camera or GoPro\nFor more information, contact our customer support at +47 123 45 678.\nPrice Details:\nDog Sledding Adventure: NOK 2,500.00 per person\nService Fee: NOK 100.00\nTotal: NOK 2,600.00 (including 12% VAT)\nTerms and Conditions:- All bookings are subject to availability.\n- Full payment is required to secure your booking.\n- Participants must be over 18 years of age.\n- Please arrive 10 minutes before the departure time.\nCancellation Policy:\n- Cancellations up to 22 days before the activity date: No penalty.\n- Cancellations 21 to 8 days before the activity date: 50% of the total amount will be charged.\n- Cancellations less than 7 days before the activity date: 100% of the total amount will be charged.\nRefund Policy:\n- Refunds will be processed in Norwegian Krone (NOK).\n- Any changes in currency exchange rates may affect the refund amount.'),
#  Document(metadata={'source': 'data/Flight_Tromso_Berlin.pdf', 'doc_id': 4}, page_content='Electronic\nTicket\nItinerary\nand\nReceipt\nMs\nNadine\nDate\nof\nIssue:\n29SEP23\nPlace\nof\nIssue:\nRiverside,\nCA\n92501\nBooking\nReference:\nBXZ2398KL4\nIATA\nNumber:\n76835421\nFlight/Date\nRoute\nDeparture\nArrival\nLatest\nCheck-in\nFlight\nDuration\nBaggage \nAllowance\nScandinavian\nAirlines \nSK\n1234\n/\n30Nov\nTromso\n- \nStockholm\n10:50\n12:50\n10:10\n02:00\n0PC\nScandinavian\nAirlines \nSK\n4321\n/\n04\nDec\nStockholm \n-\nBerlin\n17:10\n18:45\n16:30\n01:35\n0PC\nTicket\nNumber:\nTCK-4382-XY92-AB15\nFare\n191.00\nNOK\nEquivalent\nFare\nPaid\n18.00\nUSD\nTaxes,\nFees,\nOther\nCharges\n27.00\nUSD\nDomestic/International\nFees\n23.70\nUSD\nTotal\nAmount:\n68.70\nUSD\nDomestic/International\nfees\nare\nnon-refundable\nfor\nnon-refundable\nfares.\nSCANDINAVIAN\nAIRLINES\nSYSTEM\nOF\nNA\nOrg.\nNumber:\nSE\n902001-7720\n1455\nBROAD\nSTREET\nSUITE\n115\nBLOOMFIELD,\nNJ\n07003\nLIMITS\nOF\nLIABILITY\nThe\napplicable\nlimits\nof\nliability\nfor\nyour\njourney\non\na\nflight\noperated\nby\na\ncarrier\nof\nthe\nSAS\nGroup\nare\nas\nfollows:\n1.\nThere\nare\nno\nfinancial\nlimits\nin\nrespect\nof\ndeath\nor\nbodily\ninjury\nof\npassengers.\nFor\ndamages\nnot\nexceeding\n128,821\nSpecial\nDrawing\nRights\nfor\neach\npassenger,\nthe\ncarrier\nshall\nnot\nbe\nable\nto\nexclude\nor\nlimit\nits\nliability;\n2.\nIn\nrespect\nof\ndestruction,\nloss\nof,\nor\ndamage\nor\ndelay\nto\nbaggage,\n1,288\nSpecial\nDrawing\nRights\nper\npassenger\nin\nmost\ncases;\n3.\nIn\nrespect\nof\ndamage\noccasioned\nby\ndelay\nin\nthe\ncarriage\nof\npersons,\n5,346\nSpecial\nDrawing\nRights\nper\npassenger\nin\nmost\ncases.\nIf\nyour\njourney\nalso\ninvolves\ncarriage\nby\nother\nairlines,\nyou\nshould\ncontact\nthem\nfor\ninformation\non\ntheir\nlimits\nof\nliability.\nTime\nlimit\nfor\naction:\nAny\naction\nin\ncourt\nto\nclaim\ndamages\nmust\nbe\nbrought\nwithin\ntwo\nyears\nfrom\nthe\ndate\nof\narrival\nof\nthe\naircraft,\nor\nfrom\nthe\ndate\non\nwhich\nthe\naircraft\nought\nto\nhave\narrived.\nBaggage\nclaims:\nWritten\nnotice\nto\nthe\ncarrier\nmust\nbe\nmade\nwithin\n7\ndays\nof\nthe\nreceipt\nof\nchecked\nbaggage\nin\nthe\ncase\nof\ndamage,\nand,\nin\nthe\ncase\nof\ndelay,\nwithin\n21\ndays\nfrom\nthe\ndate\non\nwhich\nit\nwas\nplaced\nat\nthe\ndisposal\nof\nthe\npassenger.\nThis\nnotice\nis\nrequired\nby\nthe\nEuropean\nCommunity\nRegulation\n(EC)\nNo.\n2027/97\n(as\namended\nby\nRegulation\n(EC)\nNo.\n889/2002).\nCarriage\nand\nother\nservices\nprovided\nby\nthe\ncarrier\nare\nsubject\nto\nconditions\nof\ncarriage,\nwhich\nare\nhereby\nincorporated\nby\nreference.\nThese\nconditions\nmay\nbe\nobtained\nfrom\nthe\nissuing\ncarrier.For\ncomplete\ntext\nof\nall\nprovisions\napplicable\nand\nticket\nvalidity\nwe\nrefer\nto\nSAS\nGeneral\nConditions\nof\nCarriage\nfor\nPassengers\nand\nBaggage\nat\nhttps://www.flysas.com/\nen/legal-info/conditions-of-carriage/.\nFor\nthe\nrelevant\nrules\nregarding\nbaggage\nallowances\nwe\nrefer\nto\nSAS\nBaggage\nAllowances\nat\nwww.flysas.com.\nPassengers\nembarking\nupon\na\njourney\ninvolving\nan\nultimate\ndestination\nor\na\nstop\nin\na\ncountry\nother\nthan\nthe\ncountry\nof\ndeparture\nare\nadvised\nthat\nthe\nprovisions\nof\nan\ninternational\ntreaty\n(the\nWarsaw\nConvention,\nthe\n1999\nMontreal\nConvention,\nor\nother\ntreaty),\nas\nwell\nas\na\ncarrier’s\nown\ncontract\nof\ncarriage\nor\ntariff\nprovisions,\nmay\nbe\napplicable\nto\ntheir\nentire\njourney,\nincluding\nany\nportion\nentirely\nwithin\nthe\ncountries\nof\ndeparture\nand\ndestination.\nThe\napplicable\ntreaty\ngoverns\nand\nmay\nlimit\nthe\nliability\nof\ncarriers\nto\npassengers\nfor\ndeath\nor\npersonal\ninjury,\ndestruction\nor\nloss\nof,\nor\ndamage\nto,\nbaggage,\nand\nfor\ndelay\nof\npassengers\nand\nbaggage.\nAdditional\nprotection\ncan\nusually\nbe\nobtained\nby\npurchasing\ninsurance\nfrom\na\nprivate\ncompany.\nSuch\ninsurance\nis\nno ...

# %% [markdown]
# ## Create vectorestore - ChromaDB

# %%
# use OpenAI Embeddings
embeddings = "text-embedding-3-small"

# The vectorstore to use to index the child chunks
vectorstore = Chroma(
    collection_name="full_documents", embedding_function=OpenAIEmbeddings(model=embeddings)
)

# %% [markdown]
# ## MultiVectoreRetriever
# - this will embed the small chunks but retrieve the information from the parent document

# %%
# The storage layer for the parent documents
store = InMemoryByteStore()

# key to match child document(chunks) to parent document (raw)
id_key = "doc_id"

# create MultiVectorRetriever
retriever = MultiVectorRetriever(
    vectorstore=vectorstore,
    byte_store=store,
    id_key=id_key,
)

doc_ids = [doc.metadata['doc_id'] for doc in raw_documents]
retriever.vectorstore.add_documents(chunked_documents)
retriever.docstore.mset(list(zip(doc_ids, raw_documents)))

# %%
# cosine similarity
retriever.vectorstore.similarity_search('Booking Details for Aurora Borealis Tour')
# Out:
# [Document(metadata={'chunk_id': 0, 'doc_id': 0, 'location': 'Tromsø, Norway', 'source': 'data/aurora_borealis_tour.pdf', 'title': 'Booking Confirmation and Ticket Instructions', 'type': 'activity'}, page_content='Booking Confirmation and Ticket Instructions:Thanks for your order, Nadine. For easy access to your ticket and to be able to manage your booking on the go, download our app. November 30, 2023, at 6:30 PM From Tromsø: Aurora Borealis Tour 4 Adults (Age 0 - 99) • English • 6 hours € 555. See activity details. Get the GetYourGuide app to access your activity. Access your activity with the GetYourGuide app. Just open your tickets in the app and you’ll be ready to go.'),
#  Document(metadata={'chunk_id': 0, 'doc_id': 0, 'location': 'Tromsø, Norway', 'source': 'data/aurora_borealis_tour.pdf', 'title': 'Booking Confirmation and Ticket Instructions', 'type': 'activity'}, page_content='Booking Confirmation and Ticket Instructions:Thanks for your order, Nadine. For easy access to your ticket and to be able to manage your booking on the go, download our app. November 30, 2023, at 6:30 PM From Tromsø: Aurora Borealis Tour 4 Adults (Age 0 - 99) • English • 6 hours € 555. See activity details. Get the GetYourGuide app to access your activity. Access your activity with the GetYourGuide app. Just open your tickets in the app and you’ll be ready to go.'),
#  Document(metadata={'chunk_id': 2, 'doc_id': 0, 'location': 'Tromsø, Norway', 'source': 'data/aurora_borealis_tour.pdf', 'title': 'Tour Duration and Northern Lights Sightings', 'type': 'activity'}, page_content="Tour Duration and Northern Lights Sightings:Important information: Know before you go. Keep in mind Northern Lights sightings are not guaranteed. A refund will not be offered if these aren't visible on the day of your tour. Drop-off is only available at hotels in the center of Tromsø, not at Airbnb or other accommodation. Our tour duration has an estimated time of 6 hours. It can change from 5-8 hours depending on driving distance, weather, and aurora activity."),
#  Document(metadata={'chunk_id': 2, 'doc_id': 0, 'location': 'Tromsø, Norway', 'source': 'data/aurora_borealis_tour.pdf', 'title': 'Tour Duration and Northern Lights Sightings', 'type': 'activity'}, page_content="Tour Duration and Northern Lights Sightings:Important information: Know before you go. Keep in mind Northern Lights sightings are not guaranteed. A refund will not be offered if these aren't visible on the day of your tour. Drop-off is only available at hotels in the center of Tromsø, not at Airbnb or other accommodation. Our tour duration has an estimated time of 6 hours. It can change from 5-8 hours depending on driving distance, weather, and aurora activity.")]

# %% [markdown]
# ## Retrieval Evaluation

# %%
import pandas as pd
df_ground_truth = pd.read_csv('../data/ground-truth-data.csv')
ground_truth = df_ground_truth.to_dict(orient='records')

# %%
def compute_mrr(ranks):
    """
    Computes the Mean Reciprocal Rank (MRR) given a list of ranks.

    Args:
        ranks (list): List of ranks where each rank is the position of the relevant item.
                      A rank of 0 indicates the relevant item was not found.

    Returns:
        float: The Mean Reciprocal Rank.
    """
    reciprocal_ranks = [1 / rank if rank > 0 else 0 for rank in ranks]
    return sum(reciprocal_ranks) / len(reciprocal_ranks)

# %%
def compute_hits_and_ranks(relevant_item, retrieved_items):
    """
    Computes the hit and rank for a single query.

    Args:
        relevant_item: The relevant item (could be doc_id or (doc_id, chunk_id)).
        retrieved_items (list): List of retrieved items.

    Returns:
        tuple: (hit, rank)
            - hit (bool): True if the relevant item is in retrieved_items.
            - rank (int): Rank position of the relevant item (1-based). 0 if not found.
    """
    hit = relevant_item in retrieved_items
    try:
        rank = retrieved_items.index(relevant_item) + 1  # Ranks start from 1
    except ValueError:
        rank = 0  # Relevant item not found
    return hit, rank

# %%
def evaluate_query(ground_truth, retriever, k=5):
    """
    Evaluates the retriever's performance for a single ground truth item.

    Args:
        item (dict): A dictionary containing:
            - 'question': The query string.
            - 'doc_id': The relevant doc_id.
            - 'chunk_id': The relevant chunk_id.
        retriever: The retriever object.
        k (int): Number of top documents to consider.

    Returns:
        dict: Dictionary containing hits and ranks for both doc_id and doc_chunk.
    """
    query = ground_truth['question']
    relevant_doc_id = ground_truth['doc_id']
    relevant_chunk_id = ground_truth['chunk_id']
    relevant_doc_chunk = (relevant_doc_id, relevant_chunk_id)

    # Retrieve documents for the query
    results = retriever.vectorstore.similarity_search(query,k=k)

    # Extract retrieved doc_ids and chunks
    retrieved_doc_ids = [doc.metadata['doc_id'] for doc in results[:k]]
    retrieved_doc_chunks = [
        (doc.metadata['doc_id'], doc.metadata['chunk_id']) for doc in results[:k]
    ]

    # Compute hit and rank for doc_id
    hit_doc_id, rank_doc_id = compute_hits_and_ranks(relevant_doc_id, retrieved_doc_ids)

    # Compute hit and rank for doc_chunk
    hit_doc_chunk, rank_doc_chunk = compute_hits_and_ranks(relevant_doc_chunk, retrieved_doc_chunks)

    return {
        'hit_doc_id': hit_doc_id,
        'rank_doc_id': rank_doc_id,
        'hit_doc_chunk': hit_doc_chunk,
        'rank_doc_chunk': rank_doc_chunk
    }

# %%
from tqdm import tqdm

# Initialize lists to collect results
relevance_total_doc_id = []
relevance_total_doc_chunk = []
ranks_doc_id = []
ranks_doc_chunk = []

# Loop over all ground truth items
for item in tqdm(ground_truth):
    metrics = evaluate_query(item, retriever, k=5)
    relevance_total_doc_id.append(metrics['hit_doc_id'])
    ranks_doc_id.append(metrics['rank_doc_id'])
    relevance_total_doc_chunk.append(metrics['hit_doc_chunk'])
    ranks_doc_chunk.append(metrics['rank_doc_chunk'])
# Out:
#   0%|          | 0/235 [00:00<?, ?it/s]
#  71%|███████   | 167/235 [00:51<00:18,  3.70it/s]

# %%
# Compute overall metrics
hit_rate_doc_id = sum(relevance_total_doc_id) / len(relevance_total_doc_id) if relevance_total_doc_id else 0
hit_rate_doc_chunk = sum(relevance_total_doc_chunk) / len(relevance_total_doc_chunk) if relevance_total_doc_chunk else 0
mrr_doc_id = compute_mrr(ranks_doc_id)
mrr_doc_chunk = compute_mrr(ranks_doc_chunk)

# Print the results
print(f"Hit Rate@{5} (doc_id only): {hit_rate_doc_id}")
print(f"Hit Rate@{5} (doc_id and chunk_id): {hit_rate_doc_chunk}")
print(f"MRR (doc_id only): {mrr_doc_id}")
print(f"MRR (doc_id and chunk_id): {mrr_doc_chunk}")
# Out:
# Hit Rate@5 (doc_id only): 0.9914893617021276
# Hit Rate@5 (doc_id and chunk_id): 0.9446808510638298
# MRR (doc_id only): 0.8753191489361701
# MRR (doc_id and chunk_id): 0.7936879432624115

# %% [markdown]
# ## RAG Flow

# %%
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain.chains import create_retrieval_chain
from langchain_core.prompts import ChatPromptTemplate
from dotenv import load_dotenv
from langchain_groq import ChatGroq
from langchain_openai import ChatOpenAI
import os
load_dotenv()
GROQ_API_KEY = os.getenv('GROQ_API_KEY')

def get_llm(llm_type:str):
    if llm_type == 'groq':
        return ChatGroq(groq_api_key=GROQ_API_KEY, model_name="llama3-8b-8192")
    elif llm_type == 'openai':
        return ChatOpenAI(model='gpt-4o-mini')

def rag(input:str, retriever):
    # Define the system prompt
    system_prompt = """
    You are a travel assistant that helps people extract relevant information from documents 
    and assist in the travel questions. Based on the provided context, please answer the following question.

    Context: {context}

    Question: {input}

    Answer:
    """
    prompt = ChatPromptTemplate.from_messages(
        [
            ("system", system_prompt),
            ("human", "{input}"),
        ]
    )


    # create chain to pass the douments to the prompt
    chain = create_stuff_documents_chain(get_llm('groq'), prompt)

    # chain to retrieve the documents 
    rag_chain = create_retrieval_chain(retriever, chain)
    result = rag_chain.invoke({"input":input})
    return result['answer']

# %%
rag("What is the date and time of my flight from Tromso?",retriever)
# Out:
# 'According to the provided context, your flight from Tromso is as follows:\n\n* Flight number: SK 1234\n* Date: November 30, 2023\n* Departure time: 10:50\n* Arrival time: 12:50'

# %% [markdown]
# ## RAG Evaluation
#
# > This evaluation is something that I still need to improve. <br/>
# The high relevance can be due to the fact that all the files are related to bookings. Hence, the answers could be relevant. <br/>
# I would need to evaluate the precision and compare it to the actual document

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import PromptTemplate
llm_rag_eval = ChatOpenAI(model='gpt-4o-mini')

# create PromptTemplate
prompt = PromptTemplate(input_variables=['question','answer_llm'],template=rag_eval_prompt_template)

# %%
prompt
# Out:
# PromptTemplate(input_variables=['answer_llm', 'question'], template='You are an expert evaluator for a RAG system.\n    Your task is to analyze the relevance of the generated answer to the given question.\n    Based on the relevance of the generated answer, you will classify it\n    as "NON_RELEVANT", "PARTLY_RELEVANT", or "RELEVANT".\n    \n    Here is the data for evaluation:\n    Question: {question}\n    Generated Answer: {answer_llm}\n    \n    Please analyze the content and context of the generated answer in relation to the question\n    and provide your evaluation in parsable JSON without using code blocks:\n    {{\n      "Relevance": "NON_RELEVANT" | "PARTLY_RELEVANT" | "RELEVANT",\n      "Explanation": "[Provide a brief explanation for your evaluation]"\n    }}')

# %%
from langchain_core.output_parsers import StrOutputParser
def eval_rag(question, answer_llm,llm) -> list:
    # Define the prompt template
    rag_eval_prompt_template = """
    You are an expert evaluator for a RAG system.
    Your task is to analyze the relevance of the generated answer to the given question.
    Based on the relevance of the generated answer, you will classify it
    as "NON_RELEVANT", "PARTLY_RELEVANT", or "RELEVANT".
    
    Here is the data for evaluation:
    Question: {question}
    Generated Answer: {answer_llm}
    
    Please analyze the content and context of the generated answer in relation to the question
    and provide your evaluation in parsable JSON without using code blocks:
    {{
      "Relevance": "NON_RELEVANT" | "PARTLY_RELEVANT" | "RELEVANT",
      "Explanation": "[Provide a brief explanation for your evaluation]"
    }}""".strip()

    # Create the prompt template with LangChain
    prompt = ChatPromptTemplate.from_messages(
        [
            ("system", rag_eval_prompt_template),
        ]
    )
    parser = StrOutputParser()

    chain = prompt | llm | parser
    # Create the LLM chain

    # Execute the chain with the provided context
    result = chain.invoke({"question": question, "answer_llm":answer_llm})
    
    return result

# %%
ground_truth[0]['question']
answer_llm = rag(ground_truth[0]['question'],retriever)

# %%
from tqdm import tqdm
evaluations = []

for record in tqdm(ground_truth):
    question = record['question']
    answer_llm = rag(question, retriever) 

    evaluation = eval_rag(question, answer_llm, get_llm('openai'))
    evaluation = json.loads(evaluation)

    evaluations.append((record, answer_llm, evaluation))
# Out:
# 100%|██████████| 235/235 [14:31<00:00,  3.71s/it]

# %%
evaluations
# Out:
# [({'doc_id': 0,
#    'chunk_id': 0,
#    'question': 'What is the date and time of the Aurora Borealis Tour?'},
#   'According to the provided context, the date and time of the Aurora Borealis Tour are:\n\n* Date: November 30, 2023\n* Time: 6:30 PM\n\nThese details can be found in the initial message from GetYourGuide, under the section "What to do on the day".',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by providing the specific date and time of the Aurora Borealis Tour, which is the information being requested.'}),
#  ({'doc_id': 0,
#    'chunk_id': 0,
#    'question': 'How many adults are included in the booking?'},
#   'Based on the provided context, the booking includes a maximum of 2 adults in each of the rooms mentioned:\n\n1. Comfort Hotel Xpress Tromsø: Standard Double Room - 2 guests\n2. Brix Hostel: Standard Double Room with Shared Bathroom - 2 guests\n\nTherefore, the total number of adults included in the booking is 2 + 2 = 4 adults.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by specifying the number of adults included in the booking, providing a clear calculation based on the information given about the rooms.'}),
#  ({'doc_id': 0,
#    'chunk_id': 0,
#    'question': 'What is the total price for the Aurora Borealis Tour?'},
#   'According to the provided context, the total price for the Aurora Borealis Tour is € 555.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by providing the total price for the Aurora Borealis Tour, which is the information requested.'}),
#  ({'doc_id': 0,
#    'chunk_id': 0,
#    'question': 'In which language will the Aurora Borealis Tour be conducted?'},
#   'According to the provided context, the Aurora Borealis Tour will be conducted in English.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by stating that the Aurora Borealis Tour will be conducted in English, which is the specific information requested.'}),
#  ({'doc_id': 0,
#    'chunk_id': 0,
#    'question': 'What is the duration of the Aurora Borealis Tour?'},
#   'According to the provided context, the duration of the Aurora Borealis Tour is estimated to be 6 hours, which can change from 5 to 8 hours depending on driving distance, weather, and aurora activity.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': "The generated answer directly addresses the question by providing the estimated duration of the Aurora Borealis Tour and mentioning the factors that may affect it. This information is specifically relevant to the inquiry about the tour's duration."}),
#  ({'doc_id': 0,
#    'chunk_id': 1,
#    'question': 'Where should I go to meet my guide?'},
#   "According to the provided context, you should meet your guide outside the Scandic Ishavshotel at Fredrik Langes gate 2, 9008 Tromsø, Norway. Make sure to arrive at the meeting point 10 minutes before your chosen time so you don't lose your time slot.",
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by providing a specific location where the guide can be met, along with additional helpful information about arriving on time. This makes the answer highly relevant to the question asked.'}),
#  ({'doc_id': 0,
#    'chunk_id': 1,
#    'question': 'At what time should I arrive at the meeting point?'},
#   'According to the provided context, it is recommended to arrive at the meeting point 10 minutes before your chosen time. In this case, since the activity starts at 6:30 PM, it would be best to arrive at 6:20 PM.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by providing a specific time to arrive at the meeting point, which is 10 minutes before the activity starts at 6:30 PM. This information is directly related to the question asked.'}),
#  ({'doc_id': 0,
#    'chunk_id': 1,
#    'question': 'What is the address of the meeting point?'},
#   'According to the provided context, the meeting point address is:\n\nFredrik Langes gate 2, 9008 Tromsø, Norway\n\nYou are supposed to meet your guide outside the Scandic Ishavshotel.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer provides the exact address of the meeting point as requested in the question, along with additional context about where to meet the guide, which is pertinent information.'}),
#  ({'doc_id': 0, 'chunk_id': 1, 'question': 'Where does the activity end?'},
#   'Based on the provided context, the activity ends at the same place it began, which is outside the main entrance of the Radisson Blu Hotel Tromsø.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by specifying the location where the activity ends, which is outside the main entrance of the Radisson Blu Hotel Tromsø. This directly answers the inquiry about the endpoint of the activity.'}),
#  ({'doc_id': 0,
#    'chunk_id': 1,
#    'question': 'What is the name of the hotel outside of which I should meet my guide?'},
#   'According to the context, you should meet your guide outside the Scandic Ishavshotel.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by providing the specific name of the hotel where the guide should be met, which is exactly what the question asks for.'}),
#  ({'doc_id': 0,
#    'chunk_id': 2,
#    'question': 'Is a refund offered if the Northern Lights are not visible on the tour?'},
#   'According to the provided context, the answer is:\n\n"No, a refund will not be offered if the Northern Lights are not visible on the day of your tour."',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question about whether a refund is offered if the Northern Lights are not visible on the tour, clearly stating that no refund will be provided. This is a direct response to the inquiry.'}),
#  ({'doc_id': 0,
#    'chunk_id': 2,
#    'question': 'What is the estimated duration of the tour in Tromsø?'},
#   'According to the provided context, the estimated duration of the From Tromsø: Aurora Borealis Tour is 6 hours. However, it can change from 5-8 hours depending on driving distance, weather, and aurora activity.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by providing the estimated duration of the tour in Tromsø, stating it is 6 hours with possible variations due to various factors. This information is exactly what the question is asking for.'}),
#  ({'doc_id': 0,
#    'chunk_id': 2,
#    'question': 'Can I be dropped off at an Airbnb after the tour?'},
#   'According to the provided context, the answer is no. The tour details specify that "Drop-off is only available at hotels in the center of Tromsø, not at Airbnb or other accommodation".',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by stating that drop-off is not available at Airbnb accommodations, which is the specific information the question seeks.'}),
#  ({'doc_id': 0,
#    'chunk_id': 2,
#    'question': 'Where is the drop-off location for the tour in Tromsø?'},
#   'According to the provided document, the drop-off location for the tour in Tromsø is only available at hotels in the center of Tromsø, not at Airbnb or other accommodations.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by specifying that the drop-off location for the tour in Tromsø is at hotels in the center of Tromsø, which is the information the question seeks.'}),
#  ({'doc_id': 0,
#    'chunk_id': 2,
#    'question': 'What factors can affect the duration of the Northern Lights tour?'},
#   'According to the provided document, the duration of the Northern Lights tour can be affected by the following factors:\n\n1. Driving distance\n2. Weather\n3. Aurora activity\n\nThe tour duration is estimated to be 6 hours, but it can change from 5-8 hours depending on these factors.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by listing specific factors that can affect the duration of the Northern Lights tour, such as driving distance, weather, and aurora activity. Additionally, it provides information on the estimated duration and how it can vary, which is pertinent to the question asked.'}),
#  ({'doc_id': 0,
#    'chunk_id': 3,
#    'question': 'What is the deadline to cancel the booking for a full refund?'},
#   'According to the booking confirmation, the deadline to cancel the booking for a full refund varies depending on the booking:\n\n* For the Brix Hostel in Prague, the deadline is 4 days before arrival.\n* For the Comfort Hotel Xpress Tromsø, the deadline is 3 days before arrival.\n* For the GetYourGuide Aurora Borealis Tour, the deadline is 6:30 PM on November 29th.\n\nPlease note that these deadlines apply only to full refunds, and the cancellation policies may differ for partial refunds or no-show fees.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer provides specific deadlines for canceling bookings at different locations, directly addressing the question about the deadline for a full refund. It also notes that there may be different policies for partial refunds, which adds useful context.'}),
#  ({'doc_id': 0,
#    'chunk_id': 3,
#    'question': 'Who is the activity provider for this booking?'},
#   'According to the provided information, the activity provider for this booking is Arctic Breeze AS, and you can contact them at +47 90 98 09 19 for any questions about your activity.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by identifying the activity provider for the booking as Arctic Breeze AS and provides additional contact information, which is relevant to the inquiry.'}),
#  ({'doc_id': 0,
#    'chunk_id': 3,
#    'question': 'What is the contact phone number for Arctic Breeze AS?'},
#   'The contact phone number for Arctic Breeze AS is +47 90 98 09 19.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer provides the exact contact phone number for Arctic Breeze AS, which directly answers the question asked.'}),
#  ({'doc_id': 0,
#    'chunk_id': 3,
#    'question': 'What is the booking reference number for this reservation?'},
#   'The booking reference number for this reservation is BXZ2398KL4.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly provides the booking reference number as requested in the question, clearly addressing the query with the appropriate information.'}),
#  ({'doc_id': 0,
#    'chunk_id': 3,
#    'question': 'How can I download the receipt for my payment?'},
#   'According to the provided document, you can download the receipt for your payment by clicking on the "Download receipt" link.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': "The generated answer directly addresses the question by providing a clear method for downloading the receipt, specifically mentioning a 'Download receipt' link, which is exactly what the user is asking about."}),
#  ({'doc_id': 0,
#    'chunk_id': 4,
#    'question': 'How can I access my tickets offline for my trip?'},
#   'According to the provided Electronic Ticket, you can access your tickets offline for your trip by downloading the GetYourGuide app. The instructions are mentioned in the ticket as follows:\n\n"For easy access to your ticket and to be able to manage your booking on the go, download our app."\n\nAdditionally, it is also mentioned that you can access your ticket using the GetYourGuide app, just open your tickets in the app and you\'ll be ready to go.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by providing specific instructions on how to access tickets offline using the GetYourGuide app, which is a clear and relevant solution for accessing tickets during a trip.'}),
#  ({'doc_id': 0,
#    'chunk_id': 4,
#    'question': 'Where should I contact if I have questions about my meeting point or pickup service?'},
#   'According to the provided context, if you have questions about your meeting point, pickup service, or other queries about what happens on the day, you should contact your activity provider (Arctic Breeze AS) for assistance.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by specifying that the user should contact their activity provider for questions about the meeting point or pickup service, which aligns perfectly with the inquiry.'}),
#  ({'doc_id': 0,
#    'chunk_id': 4,
#    'question': 'What should I do if I need to reschedule or cancel my booking?'},
#   'According to the provided document, if you need to reschedule or cancel your booking, you should follow these steps:\n\n* Cancellation:\n\t+ For the hotel booking at Brix Hostel, you can cancel free of charge until 4 days before arrival. If you cancel in the 4 days before arrival, the cancellation fee will be the total price of the reservation. If you don\'t show up, the no-show fee will be the same as the cancellation fee.\n\t+ For the bus/train ticket, cancellation is not possible if you cancel less than 15 minutes before the departure time. If you cancel more than 15 minutes before the departure time, you can cancel for free. However, rebooking is only possible for 0 EUR if you cancel more than 15 minutes before the departure time.\n* Rescheduling:\n\t+ For the hotel booking at Brix Hostel, changes can be made free of charge until 3 days before arrival. If you change your booking in the 3 days before arrival, the applicable charges will apply.\n\t+ For the bus/train ticket, changes can be made free of charge if you make the changes at least 30 minutes before the scheduled departure time. The applicable charges will apply if you make changes less than 30 minutes before the scheduled departure time.\n\nYou can also make changes or cancel your booking online via the "My Reservations" section or contact the relevant party (hotel or bus/train company) directly to make changes or cancel your booking.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by providing detailed information on both rescheduling and canceling bookings, including specific policies for a hotel and bus/train tickets. It clearly outlines the necessary steps and conditions for both actions, making it highly relevant to the question asked.'}),
#  ({'doc_id': 0,
#    'chunk_id': 4,
#    'question': 'Who are the managing directors of GetYourGuide Deutschland GmbH?'},
#   'According to the provided context, the managing directors of GetYourGuide Deutschland GmbH are:\n\n1. Johannes Reck\n2. Tao Tao\n3. Nils Chrestin',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly provides the names of the managing directors of GetYourGuide Deutschland GmbH, which is precisely what the question asks for.'}),
#  ({'doc_id': 0,
#    'chunk_id': 4,
#    'question': 'Where is GetYourGuide Deutschland GmbH registered?'},
#   'According to the provided email, GetYourGuide Deutschland GmbH is registered at the District Court of Charlottenburg HRB 132059 B, VAT ID No. DE276456081.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by providing the specific location where GetYourGuide Deutschland GmbH is registered, including the District Court and registration number, which is precisely what was asked.'}),
#  ({'doc_id': 1,
#    'chunk_id': 0,
#    'question': 'What is the price for 1 unit for 2 guests?'},
#   'According to the provided documents, the price for 1 unit for 2 guests is:\n\n* For Comfort Hotel Xpress Tromsø: €910\n* For Brix Hostel: €167.97',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by providing the price for 1 unit for 2 guests at two different locations, which is exactly what the question is asking for.'}),
#  ({'doc_id': 1,
#    'chunk_id': 0,
#    'question': 'Are additional supplements like an extra bed included in the total price?'},
#   'According to the documents, additional supplements (e.g. extra bed) are not added in this total.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question about whether additional supplements like an extra bed are included in the total price, clearly stating that they are not included.'}),
#  ({'doc_id': 1,
#    'chunk_id': 0,
#    'question': "What happens if guests don't show up or cancel?"},
#   "According to the provided context, if guests don't show up or cancel, the following applies:\n\n* For Comfort Hotel Xpress Tromsø:\n\t+ If guests cancel in the 3 days before arrival, the cancellation fee will be the total price of the reservation.\n\t+ If guests don't show up, the no-show fee will be the same as the cancellation fee.\n* For Brix Hostel:\n\t+ If guests cancel in the 4 days before arrival, the cancellation fee will be the total price of the reservation.\n\t+ If guests don't show up, the no-show fee will be the same as the cancellation fee.\n\nAdditionally, it's mentioned that applicable taxes may still be charged by the property even if guests don't show up or cancel.",
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question about the consequences of guests not showing up or canceling by providing specific details about cancellation and no-show fees for two different accommodations. It clearly explains the financial implications for both scenarios, making it highly relevant to the question asked.'}),
#  ({'doc_id': 1,
#    'chunk_id': 0,
#    'question': 'Will applicable taxes be charged if guests cancel?'},
#   'According to the provided documents, yes, applicable taxes may still be charged by the property if you don\'t show up or cancel. This is mentioned in the "Additional information" section under the "PRICE" heading.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question about whether applicable taxes will be charged upon cancellation, confirming that they may be charged and referencing the relevant section for more information.'}),
#  ({'doc_id': 1,
#    'chunk_id': 0,
#    'question': 'Where is the location of the booking?'},
#   'According to the provided context, the location of the booking is:\n\n1. Comfort Hotel Xpress Tromsø, Grønnegata 35, 9008 Tromsø, Norway (for Ms. Nadine)\n2. Brix Hostel, Roháčova 132/15, Prague, 130 00, Czech Republic (for LLM Zoomcamp)',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by providing specific locations of bookings, including names and addresses, which are exactly what is being asked for.'}),
#  ({'doc_id': 1,
#    'chunk_id': 1,
#    'question': 'What is the maximum occupancy for the Standard Double Room?'},
#   'According to the provided documents, the maximum occupancy for both Standard Double Rooms is:\n\n1. Standard Double Room at Comfort Hotel Xpress Tromsø: "for max. 2 people."\n2. Standard Double Room at Brix Hostel: "for max. 2 people."\n\nSo, the maximum occupancy for both rooms is 2 guests.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by providing the maximum occupancy for the Standard Double Room, specifying that it is 2 guests for both listed hotels. This information is exactly what was asked for.'}),
#  ({'doc_id': 1,
#    'chunk_id': 1,
#    'question': 'Is there a meal option included with the Standard Double Room?'},
#   'According to the provided context, there is no meal option included with the Standard Double Room.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question about whether there is a meal option included with the Standard Double Room, stating clearly that there is no meal option included, which is the information requested.'}),
#  ({'doc_id': 1,
#    'chunk_id': 1,
#    'question': 'What amenities are included in the Standard Double Room?'},
#   'Based on the provided context, the Standard Double Room includes the following amenities:\n\n* Shower\n* Toilet\n* Towels\n* Linen\n* Desk\n* Seating Area\n* Heating\n* Hairdryer\n* Toilet paper\n* Cable channels\n* Upper floors accessible by elevator (in the case of Comfort Hotel Xpress Tromsø)\n* Upper floors accessible by stairs only (in the case of Brix Hostel)\n\nNote that these amenities may vary depending on the specific hotel and room type.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by listing the specific amenities included in the Standard Double Room, providing clear and relevant information. The mention of potential variations based on different hotels also adds context without detracting from the relevance.'}),
#  ({'doc_id': 1,
#    'chunk_id': 1,
#    'question': 'What is the bed size in the Standard Double Room?'},
#   'The bed size in the Standard Double Room is 1 double bed (131-150 cm wide).',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by providing the specific bed size information for the Standard Double Room, stating that it includes 1 double bed with the width range of 131-150 cm.'}),
#  ({'doc_id': 1,
#    'chunk_id': 1,
#    'question': 'How can guests access the upper floors in the accommodation?'},
#   'According to the provided documents, guests can access the upper floors in the Comfort Hotel Xpress Tromsø using the elevator, and in the Brix Hostel, the upper floors are accessible by stairs only.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by explaining how guests can access the upper floors in two specific accommodations, detailing both the use of an elevator and stairs.'}),
#  ({'doc_id': 1,
#    'chunk_id': 2,
#    'question': 'What is the daily cost for private parking at the hotel?'},
#   'According to the provided context, the daily cost for private parking at the Brix Hostel is € 12 per day.\n\nAdditionally, the Comfort Hotel Xpress Tromsø also offers private parking on site, and the daily cost for this is € 20 per day.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by providing the daily cost for private parking at the hotel, specifically mentioning both the Brix Hostel and the Comfort Hotel Xpress Tromsø, which helps the user understand the parking costs at these locations.'}),
#  ({'doc_id': 1,
#    'chunk_id': 2,
#    'question': 'Is WiFi available in all areas of the hotel?'},
#   'According to the provided context, WiFi is available in all areas and is free of charge.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by confirming that WiFi is available in all areas of the hotel, which is the information being requested.'}),
#  ({'doc_id': 1,
#    'chunk_id': 2,
#    'question': 'Do I need to make a reservation for private parking at the hotel?'},
#   'According to the provided documents, for the Comfort Hotel Xpress Tromsø, private parking is possible on site, but reservation is not possible, and it costs € 20 per day.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question about the need for a reservation for private parking by stating that reservation is not possible at the hotel, which is the key information asked in the question.'}),
#  ({'doc_id': 1,
#    'chunk_id': 2,
#    'question': 'What is the cost of parking per day at the hotel?'},
#   'According to the provided context, the cost of parking per day at the hotel is:\n\n* At Brix Hostel: € 12 per day (private parking is possible at a location nearby, reservation is not needed)\n* At Comfort Hotel Xpress Tromsø: € 20 per day (private parking is possible on site, reservation is not possible)',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by providing the specific costs of parking per day at two hotels, which is exactly what the question asks for.'}),
#  ({'doc_id': 1,
#    'chunk_id': 2,
#    'question': 'Is there an extra charge for WiFi at the hotel?'},
#   'According to the provided context, WiFi is available in all areas and is free of charge.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by stating that WiFi is available for free, thereby confirming that there is no extra charge for it at the hotel.'}),
#  ({'doc_id': 1,
#    'chunk_id': 3,
#    'question': 'What is the booking confirmation number?'},
#   'The booking confirmation numbers mentioned in the provided context are:\n\n1. For Comfort Hotel Xpress Tromsø:\n   CONFIRMATION NUMBER: 3645.982.716\n   PIN CODE: 9032\n\n2. For Brix Hostel:\n   CONFIRMATION NUMBER: 3645.982.716 (same as above)\n\n3. For Dog Sledding Adventure:\n   Booking ID: BKD-56273',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer provides specific booking confirmation numbers in direct response to the question about the booking confirmation number. It includes relevant details for multiple bookings, addressing the inquiry accurately.'}),
#  ({'doc_id': 1,
#    'chunk_id': 3,
#    'question': 'What is the PIN code for the booking?'},
#   'According to the provided document, the PIN code for the booking is: 9032.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly provides the requested information, specifically stating the PIN code for the booking as 9032, which aligns perfectly with the question asked.'}),
#  ({'doc_id': 1,
#    'chunk_id': 3,
#    'question': 'How many days before arrival can you cancel free of charge?'},
#   'Based on the provided information, the cancellation policies are as follows:\n\nFor Comfort Hotel Xpress Tromsø:\n- You may cancel free of charge until 3 days before arrival.\n\nFor Brix Hostel:\n- You may cancel free of charge until 4 days before arrival.\n\nSo, the answer is:\n\nYou can cancel free of charge 3 days before arrival for Comfort Hotel Xpress Tromsø, and 4 days before arrival for Brix Hostel.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer provides specific information regarding the cancellation policies for two different accommodations, directly addressing the question about how many days before arrival one can cancel free of charge.'}),
#  ({'doc_id': 1,
#    'chunk_id': 3,
#    'question': 'What is the cancellation fee if you cancel within 3 days before arrival?'},
#   'According to the provided context, if you cancel within 3 days before arrival, the cancellation fee will be the total price of the reservation.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question about the cancellation fee for canceling within 3 days before arrival, providing a clear and specific response regarding the fee being the total price of the reservation.'}),
#  ({'doc_id': 1, 'chunk_id': 3, 'question': 'What is the no-show fee?'},
#   'According to the documents provided, the no-show fee is the same as the cancellation fee, which is the total price of the reservation.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question about the no-show fee by defining it as the same as the cancellation fee, providing clear and relevant information regarding the cost associated with not showing up for a reservation.'}),
#  ({'doc_id': 1,
#    'chunk_id': 4,
#    'question': 'What is the check-in date and time for the booking?'},
#   'Based on the provided context, the check-in date and time for the booking are:\n\n* Check-in date: 30 November\n* Check-in time: 15:00 - 00:00',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly provides the requested check-in date and time for the booking, clearly addressing the question asked.'}),
#  ({'doc_id': 1,
#    'chunk_id': 4,
#    'question': 'What is the check-out date and time for the booking?'},
#   'According to the document, the check-out date is Monday, 4th December, and the check-out time is Until 12:00.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer provides specific information regarding the check-out date and time as requested in the question. It clearly states both the date and the time, which directly addresses the query.'}),
#  ({'doc_id': 1,
#    'chunk_id': 4,
#    'question': 'Where is the location of the booking?'},
#   'Based on the provided context, the location of the booking is:\n\n* For the Comfort Hotel Xpress Tromsø, the address is: Grønnegata 35, 9008 Tromsø, Norway.\n* For the Brix Hostel, the address is: Roháčova 132/15, Prague, 130 00, Czech Republic.\n\nPlease note that there are two separate bookings mentioned in the context: one for Comfort Hotel Xpress Tromsø and another for Brix Hostel.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question about the location of the booking by providing specific addresses for both hotels mentioned, which is exactly what the question is asking for.'}),
#  ({'doc_id': 1,
#    'chunk_id': 4,
#    'question': 'What is the latest time I can check in on 30th November?'},
#   'According to the document, the check-in time for 30th November is Thursday, 15:00 - 00:00, which means the latest time you can check in is 00:00 (midnight) on 30th November.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by providing the specific latest check-in time of 00:00 on 30th November, which is exactly what was asked.'}),
#  ({'doc_id': 1,
#    'chunk_id': 4,
#    'question': 'Until what time is check-out allowed on 4th December?'},
#   'According to the document, check-out is allowed until 12:00 on 4th December.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by providing the specific check-out time of 12:00 on 4th December, which is exactly what was asked.'}),
#  ({'doc_id': 2,
#    'chunk_id': 0,
#    'question': 'What is the departure date and time from Berlin?'},
#   'According to the provided context, the departure date and time from Berlin are:\n\n* Date: 07.09.2024\n* Time: 14:25 Uhr (which is equivalent to 2:25 PM)\n\nThis information is mentioned in the "Station/Transfer" section of the document.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer provides the specific departure date and time from Berlin, which directly addresses the question asked.'}),
#  ({'doc_id': 2,
#    'chunk_id': 0,
#    'question': 'Where is the departure location in Berlin?'},
#   'According to the document, the departure location in Berlin is Berlin ZOB (Zentraler Omnibus Bahnhof) am Funkturm.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by providing the specific departure location in Berlin, which is Berlin ZOB (Zentraler Omnibus Bahnhof) am Funkturm. This information is pertinent to the inquiry about where to find the departure location.'}),
#  ({'doc_id': 2,
#    'chunk_id': 0,
#    'question': 'What is the arrival date and time in Prague?'},
#   'According to the provided document, the arrival date and time in Prague is:\n\nDate: 07.09.2024\nTime: 14:25 Uhr\nLocation: Prag Busbahnhof (ÚAN Florenc)',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer provides the specific arrival date and time in Prague, directly addressing the question asked.'}),
#  ({'doc_id': 2,
#    'chunk_id': 0,
#    'question': 'Where is the arrival location in Prague?'},
#   'According to the provided document, the arrival location in Prague is "Prag Busbahnhof (ÚAN Florenc)" with an arrival time of 12:30 PM.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': "The generated answer directly addresses the question by providing the specific arrival location in Prague, which is 'Prag Busbahnhof (ÚAN Florenc)', along with an arrival time of 12:30 PM. This information is pertinent and clearly answers the question asked."}),
#  ({'doc_id': 2,
#    'chunk_id': 0,
#    'question': 'How many tickets are booked and for whom?'},
#   'According to the provided context, 1 ticket is generated for 1 person.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by specifying that 1 ticket is booked for 1 person, which aligns with the inquiry about the number of tickets booked and for whom.'}),
#  ({'doc_id': 2,
#    'chunk_id': 1,
#    'question': 'What is the total price listed in the booking information?'},
#   'According to the provided context, the total price listed in the booking information for the Standard Double Room at the Comfort Hotel Xpress Tromsø is € 910.\n\nFor the Standard Double Room with Shared Bathroom at the Brix Hostel, the total price listed is € 167.97.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by providing the total price listed in the booking information for two different accommodations, which is relevant to the inquiry about total prices.'}),
#  ({'doc_id': 2,
#    'chunk_id': 1,
#    'question': 'What is the booking number and the date it was booked?'},
#   'According to the provided electronic ticket, itinerary, and receipt, the booking number is BXZ2398KL4 and the date it was booked is not explicitly mentioned. However, the "Date of Issue" is mentioned as 29SEP23, which implies that the booking was made on September 29, 2023.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': "The generated answer provides the booking number (BXZ2398KL4) as requested in the question. It also attempts to offer information about the booking date, clarifying that while the exact date isn't mentioned, the 'Date of Issue' indicates the booking date as September 29, 2023. This directly addresses both aspects of the question."}),
#  ({'doc_id': 2,
#    'chunk_id': 1,
#    'question': 'What is the NETTO price mentioned in the document?'},
#   'According to the document, the NETTO price is 7,64 €.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by providing the specific NETTO price mentioned in the document, which is exactly what was asked for.'}),
#  ({'doc_id': 2,
#    'chunk_id': 1,
#    'question': 'Was there any VAT (MWST) applied to the booking?'},
#   'According to the provided document, there was no VAT (MWST) applied to the booking. The document states:\n\n"--MWST. 0 %"\n\nThis indicates that the booking does not have any Value-Added Tax (VAT) applied.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': "The generated answer directly addresses the question regarding the application of VAT (MWST) to the booking by confirming that there was no VAT applied, supported by a reference to the document stating 'MWST. 0 %'. This provides clear and relevant information in response to the question."}),
#  ({'doc_id': 2,
#    'chunk_id': 1,
#    'question': 'How was the payment for this booking made?'},
#   'According to the provided context, the payment for the booking was made by credit card.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question about how the payment for the booking was made by specifying that it was made by credit card, which is the correct and relevant information.'}),
#  ({'doc_id': 2,
#    'chunk_id': 2,
#    'question': 'What is the address of FlixBus DACH GmbH?'},
#   'The address of FlixBus DACH GmbH is Karl-Liebknecht-Straße 33, D-10178 Berlin, USt-IdNr.: DE278362610.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer provides the exact address of FlixBus DACH GmbH, directly addressing the question asked.'}),
#  ({'doc_id': 2,
#    'chunk_id': 2,
#    'question': 'Who are the managing directors of Flix SE?'},
#   'Based on the provided document, the managing directors of Flix SE are:\n\n1. André Schwämmlein\n2. Daniel Krauss',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly provides the names of the managing directors of Flix SE, which is precisely what the question is asking for.'}),
#  ({'doc_id': 2, 'chunk_id': 2, 'question': 'Where is Flix SE registered?'},
#   'According to the provided document, Flix SE is registered in Germany. The address mentioned is:\n\nFlix SE\nFriedenheimer Brücke\n16\nD-80639 München\n\nAdditionally, the document mentions that Flix SE is a company registered with the Commercial Register (Handelsregister) of the Local Court (Amtsgericht) of Munich (HRB 274912) and has a German Tax Identification Number (USt-ID-Nr. DE 283764680).',
#   {'Relevance': 'RELEVANT',
#    'Explanation': "The generated answer directly addresses the question by providing the location of Flix SE's registration, including specific details about the address and relevant registration information in Germany."}),
#  ({'doc_id': 2,
#    'chunk_id': 2,
#    'question': 'What is the VAT identification number for FlixBus DACH GmbH?'},
#   'The VAT identification number for FlixBus DACH GmbH is DE278362610.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly provides the VAT identification number for FlixBus DACH GmbH, which is the exact information requested in the question.'}),
#  ({'doc_id': 2,
#    'chunk_id': 2,
#    'question': 'Is Flix SE eligible for input tax deduction?'},
#   'According to the provided document, Flix SE is not eligible for input tax deduction. The document states: "*Berechtigt nicht zum Vorsteuerabzug*" which is German for "Not eligible for input tax deduction".',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by stating that Flix SE is not eligible for input tax deduction and supports this claim with a reference to the document that confirms this information in both English and German. This clearly provides the necessary information to answer the question.'}),
#  ({'doc_id': 2,
#    'chunk_id': 3,
#    'question': 'Where can I find the general terms and booking conditions for ticket bookings?'},
#   'According to the provided context, you can find the general terms and booking conditions for ticket bookings by visiting the following links:\n\n1. Flix SE: https://www.flixbus.de/agb (Allgemeine Geschäfts- und Buchungsbedingungen der Flix SE)\n2. Flix SE: https://www.flixbus.de/abb-auswahl (Allgemeine Beförderungsbedingungen des jeweiligen Beförderers)\n3. Scandinavian Airlines (SAS): https://www.flysas.com/en/legal-info/conditions-of-carriage/ (SAS General Conditions of Carriage for Passengers and Baggage)\n\nAdditionally, you can also find the general terms and booking conditions for RegioJet tickets on their website at www.regiojet.cz.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by providing specific links to the general terms and booking conditions for ticket bookings from multiple sources, including Flix SE and Scandinavian Airlines. This information is relevant and useful for someone looking to find booking conditions.'}),
#  ({'doc_id': 2,
#    'chunk_id': 3,
#    'question': 'Where are the general transportation conditions of the respective carrier available?'},
#   "According to the provided information, the general transportation conditions of the respective carrier are available at:\n\n* https://www.flysas.com/en/legal-info/conditions-of-carriage/\n* https://www.flysas.com/en/baggage-allowances/\n* SAS General Conditions of Carriage for Passengers and Baggage\n* SAS Baggage Allowances\n\nAdditionally, the applicable treaty (Warsaw Convention, the 1999 Montreal Convention, or other treaty) and the carrier's own contract of carriage or tariff provisions may be applicable to the entire journey, including any portion entirely within the countries of departure and destination.",
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by providing links and references to where the general transportation conditions of the respective carrier are available. It includes specific URLs and mentions the SAS General Conditions of Carriage, which is pertinent to the inquiry.'}),
#  ({'doc_id': 2,
#    'chunk_id': 3,
#    'question': 'Who is the carrier or concession holder for my connection?'},
#   'According to the provided context, the carrier or concession holder for your connection is Scandinavian Airlines (SK) and Flixbus (FlixBus).',
#   {'Relevance': 'RELEVANT',
#    'Explanation': "The generated answer directly addresses the question by providing the names of the carriers or concession holders for the connection, which are Scandinavian Airlines and Flixbus, thus making it relevant to the user's inquiry."}),
#  ({'doc_id': 2,
#    'chunk_id': 3,
#    'question': 'Where can I find the carrier information for my connection?'},
#   'According to the provided context, you can find the carrier information for your connection on the receipt/booking confirmation email from GetYourGuide, which states:\n\n"What to do on the day\nWhere to go Fredrik Langes gate 2, 9008 Tromsø,\nNorway Meet your guide outside the Scandic Ishavshotel.\nWhen to arrive\n6:20 PM - Arrive at the meeting point 10 minutes before \nyour chosen time so you don\'t lose your time slot.\nWhere your activity ends\nYour activity will end at the same place it began.\nImportant information\nKnow before you go Keep in mind Northern Lights\nsightings are not guaranteed. A refund will not be offered\nif these aren\'t visible on the day of your tour Drop-off is\nonly available at hotels in the center of Tromsø, not at\nAirbnb or other accommodation Our tour duration has an\nestimated time of 6 hours. It can change from 5-8 hours.\nThis depend on driving distance, weather and aurora\nactivity.\nCancellation policy\nCancel before 6:30 PM on November 29th for a full\nrefund\nManage your booking\nYour activity provider is Arctic Breeze AS\nContact them if you have any questions about your\nactivity.+47 90 98 09 19 Email\nBooking reference RM6K4FLS\nPIN aBCdEg1\nYou paid € 555"\n\nThe carrier information is listed as "Arctic Breeze AS" with a contact number (+47 90 98 09 19) and email address.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer provides specific information about where to find the carrier information for the connection, explicitly stating that it can be found on the booking confirmation email from GetYourGuide. It also identifies the activity provider, Arctic Breeze AS, which is directly relevant to the question asked.'}),
#  ({'doc_id': 2,
#    'chunk_id': 3,
#    'question': 'What website provides the general terms and booking conditions of Flix SE?'},
#   'According to the provided document, the website that provides the general terms and booking conditions of Flix SE is: https://www.flixbus.de/agb',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by providing the specific website where the general terms and booking conditions of Flix SE can be found, which is exactly what was asked.'}),
#  ({'doc_id': 3,
#    'chunk_id': 0,
#    'question': "What is the Booking ID for Nadine's dog sledding adventure?"},
#   "The Booking ID for Nadine's dog sledding adventure is BKD-56273.",
#   {'Relevance': 'RELEVANT',
#    'Explanation': "The generated answer directly provides the Booking ID for Nadine's dog sledding adventure, which is the specific information requested in the question."}),
#  ({'doc_id': 3,
#    'chunk_id': 0,
#    'question': "Which travel agency handled Nadine's booking?"},
#   'According to the document, Nadine\'s booking for the Dog Sledding Adventure was handled by "Nordic Adventures AS".',
#   {'Relevance': 'RELEVANT',
#    'Explanation': "The generated answer directly addresses the question by clearly stating that 'Nordic Adventures AS' handled Nadine's booking, making it fully relevant to the inquiry."}),
#  ({'doc_id': 3,
#    'chunk_id': 0,
#    'question': "On what date was Nadine's dog sledding adventure booking made?"},
#   "According to the context, Nadine's dog sledding adventure booking was made on September 15, 2023.",
#   {'Relevance': 'RELEVANT',
#    'Explanation': "The generated answer directly provides the specific date of Nadine's dog sledding adventure booking, which is the exact information requested in the question."}),
#  ({'doc_id': 3,
#    'chunk_id': 0,
#    'question': "Where is the location of Nadine's dog sledding adventure?"},
#   "According to the booking confirmation, the location of Nadine's dog sledding adventure is outside the main entrance of the Radisson Blu Hotel Tromsø.",
#   {'Relevance': 'RELEVANT',
#    'Explanation': "The generated answer directly addresses the question by providing a specific location for Nadine's dog sledding adventure, which is outside the main entrance of the Radisson Blu Hotel Tromsø."}),
#  ({'doc_id': 3,
#    'chunk_id': 0,
#    'question': 'What is the name of the customer who booked the dog sledding adventure?'},
#   'The name of the customer who booked the dog sledding adventure is Nadine.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by providing the name of the customer who booked the dog sledding adventure, which is exactly what was asked.'}),
#  ({'doc_id': 3,
#    'chunk_id': 1,
#    'question': 'What is the date of the activity?'},
#   'According to the provided context, the date of the Dog Sledding Adventure activity is December 3, 2023, and it is scheduled from 8:45 AM to 3:45 PM.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly provides the date of the Dog Sledding Adventure activity, which is the specific information requested in the question.'}),
#  ({'doc_id': 3,
#    'chunk_id': 1,
#    'question': 'What are the start and end times of the activity?'},
#   'According to the provided context, the start and end times of the activity are:\n\n* Start time: 8:45 AM\n* End time: 3:45 PM',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by providing the specific start and end times of the activity, which is exactly what was asked.'}),
#  ({'doc_id': 3,
#    'chunk_id': 1,
#    'question': 'Where is the meeting point for the activity?'},
#   'The meeting point for the Dog Sledding Adventure is outside the main entrance of the Radisson Blu Hotel Tromsø.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by providing the specific location of the meeting point for the activity, which is the Dog Sledding Adventure outside the Radisson Blu Hotel Tromsø.'}),
#  ({'doc_id': 3,
#    'chunk_id': 1,
#    'question': 'Which hotel is specified as the meeting point?'},
#   'According to the provided context, the meeting point specified is the Radisson Blu Hotel Tromsø (Outside the main entrance) for the Dog Sledding Adventure on December 3, 2023.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by specifying the Radisson Blu Hotel Tromsø as the meeting point, which is exactly what was asked in the question.'}),
#  ({'doc_id': 3,
#    'chunk_id': 1,
#    'question': 'In which city and country is the activity taking place?'},
#   'According to the booking confirmation for the Dog Sledding Adventure, the activity is taking place in Tromsø, Norway.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly provides the city (Tromsø) and country (Norway) where the activity is taking place, which directly addresses the question asked.'}),
#  ({'doc_id': 3,
#    'chunk_id': 2,
#    'question': 'What type of socks should I bring for the dog sledding adventure?'},
#   'According to the booking confirmation, you should bring "Wool socks" for the dog sledding adventure.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': "The generated answer directly addresses the question by specifying the type of socks to bring for the dog sledding adventure, which is 'Wool socks'. This information is pertinent and aligns with the inquiry about appropriate attire for the activity."}),
# ...
#   'According to the context, it is not possible to cancel the booking less than 15 minutes before departure. The cancellation terms state: "Cancellation terms: more than 15 minutes: 0 %, less than 15 minutes: not possible".',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question about whether it is possible to cancel a booking less than 15 minutes before departure. It clearly states that cancellation is not possible within that timeframe, which aligns with the inquiry made in the question.'}),
#  ({'doc_id': 7,
#    'chunk_id': 1,
#    'question': 'What is the rebooking fee if the booking is rebooked more than 15 minutes before departure?'},
#   'According to the provided context, the rebooking terms state: "more than 15 minutes: by cancellation for 0 EUR". This means that if the booking is rebooked more than 15 minutes before departure, the rebooking fee is zero (0 EUR).',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question about the rebooking fee when the booking is rebooked more than 15 minutes before departure, clearly stating that the fee is zero (0 EUR). This is precisely the information requested in the question.'}),
#  ({'doc_id': 7,
#    'chunk_id': 1,
#    'question': 'Can the booking be rebooked less than 15 minutes before departure?'},
#   'According to the provided document, the rebook terms state that "less than 15 minutes: not possible". Therefore, the booking cannot be rebooked less than 15 minutes before departure.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by stating that rebooking is not possible less than 15 minutes before departure, which is exactly what the question inquires about.'}),
#  ({'doc_id': 7,
#    'chunk_id': 1,
#    'question': 'What is the departure location and destination mentioned in the document?'},
#   'According to the document, the flights mentioned are:\n\n1. Scandinavian Airlines (SK) 1234 / 30Nov: Departure from Tromso, Arrival in Stockholm.\n2. Scandinavian Airlines (SK) 4321 / 04Dec: Departure from Stockholm, Arrival in Berlin.\n\nAdditionally, there is another flight mentioned:\n\n1. Norwegian (DY) 1123 / 30Nov: Departure from Berlin-Brandenburg (BER), Terminal 2, Arrival in Tromso (TOS).\n\nSo, the departure locations and destinations mentioned in the document are:\n\n* Tromso (Departure) - Stockholm (Arrival)\n* Stockholm (Departure) - Berlin (Arrival)\n* Berlin-Brandenburg (Departure) - Tromso (Arrival)',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by providing specific departure locations and destinations mentioned in the document. It lists multiple flights with clear details about where each flight departs from and arrives at, thus fully answering the question.'}),
#  ({'doc_id': 7,
#    'chunk_id': 2,
#    'question': 'What is required to log in and manage my reservation in the online bus/train ticket reservation system?'},
#   'To log in and manage your reservation in the online bus/train ticket reservation system, you will need to have your ticket number or QR code.',
#   {'Relevance': 'PARTLY_RELEVANT',
#    'Explanation': 'The generated answer mentions needing a ticket number or QR code to log in and manage a reservation, which is somewhat relevant. However, it does not provide a complete answer as it does not specify any other potential requirements, such as a username, password, or other authentication methods that may be necessary for logging in.'}),
#  ({'doc_id': 7,
#    'chunk_id': 2,
#    'question': 'Who administers the online bus/train ticket reservation system used by RegioJet?'},
#   'The online bus/train ticket reservation system used by RegioJet is administrated by STUDENT AGENCY k.s., Czech Republic.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by identifying STUDENT AGENCY k.s. as the entity that administers the online bus/train ticket reservation system used by RegioJet, providing a clear and accurate response.'}),
#  ({'doc_id': 7,
#    'chunk_id': 2,
#    'question': 'Is it necessary to have anything other than the ticket number or QR code to board the bus/train?'},
#   'According to the provided context, passengers only need to have the ticket number or QR code to get on the board, unless the conditions say otherwise.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by stating that passengers only need the ticket number or QR code to board, which aligns with the query about necessity. It also acknowledges that there may be exceptions, indicating a thorough understanding of the boarding requirements.'}),
#  ({'doc_id': 7,
#    'chunk_id': 2,
#    'question': 'Which company operates the online bus/train ticket reservation system for RegioJet?'},
#   'According to the provided context, the online bus/train ticket reservation system utilized by RegioJet is administrated by STUDENT AGENCY k.s., Czech Republic.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by identifying STUDENT AGENCY k.s. as the company that operates the online bus/train ticket reservation system for RegioJet, which is the specific information requested.'}),
#  ({'doc_id': 7,
#    'chunk_id': 2,
#    'question': 'What are the departure and arrival locations for the bus/train route from Prague to Berlin?'},
#   'According to the provided context, the departure location is Prague Busbahnhof (ÚAN Florenc) and the arrival location is Berlin ZOB.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer provides specific departure and arrival locations for the bus/train route from Prague to Berlin, directly addressing the question asked.'}),
#  ({'doc_id': 7,
#    'chunk_id': 3,
#    'question': 'What is the website for RegioJet?'},
#   'The website for RegioJet is www.regiojet.cz.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly provides the requested information, which is the website for RegioJet, making it fully relevant to the question.'}),
#  ({'doc_id': 7,
#    'chunk_id': 3,
#    'question': 'What is the phone number for RegioJet?'},
#   'The phone number for RegioJet is +420 222 222 222.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly provides the phone number for RegioJet, which is the information requested in the question.'}),
#  ({'doc_id': 7,
#    'chunk_id': 3,
#    'question': 'Where does the RegioJet bus depart from in Prague?'},
#   'According to the provided document, the RegioJet bus departs from Prague, ÚAN Florenc.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by stating the specific location where the RegioJet bus departs from in Prague, which is ÚAN Florenc.'}),
#  ({'doc_id': 7,
#    'chunk_id': 3,
#    'question': 'Where does the RegioJet bus arrive in Berlin?'},
#   'According to the provided document, the RegioJet bus arrives in Berlin at the "ZOB am Funkturm" at 5:00 PM.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by providing the specific location where the RegioJet bus arrives in Berlin, along with the time of arrival. This is exactly what the question is asking for.'}),
#  ({'doc_id': 7,
#    'chunk_id': 3,
#    'question': 'What is the Tax Identification Number (TIN) for SA - STUDENT AGENCY k.s.?'},
#   'According to the provided document, the Tax Identification Number (TIN) for SA - STUDENT AGENCY k.s. is CZ25317071.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by providing the specific Tax Identification Number (TIN) for SA - STUDENT AGENCY k.s., which is the information requested in the question.'}),
#  ({'doc_id': 7,
#    'chunk_id': 4,
#    'question': 'What are the acceptable travel documents for EU or Schengen Area members?'},
#   'According to the provided document, for EU or Schengen Area members, a valid travel document is an ID card.',
#   {'Relevance': 'PARTLY_RELEVANT',
#    'Explanation': 'The generated answer mentions that a valid travel document for EU or Schengen Area members is an ID card, which is relevant information. However, it does not provide a comprehensive list of acceptable travel documents, which would enhance its relevance to the question.'}),
#  ({'doc_id': 7,
#    'chunk_id': 4,
#    'question': 'Where can passengers find more information about current travel regulations?'},
#   'According to the provided document, passengers can find more information about current travel regulations on the RegioJet website at regiojet.com/covid.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by providing a specific source (the RegioJet website) where passengers can find information about current travel regulations. This makes the answer highly relevant to the inquiry.'}),
#  ({'doc_id': 7,
#    'chunk_id': 4,
#    'question': 'Will passengers be allowed to travel with a stay permit or driving license?'},
#   'No, according to the document, passengers are kindly requested to present a valid travel document - ID card (only members EU or Schengen Area) or passport, when boarding the bus. A stay permit, copies of documents, driving licence, etc. do not constitute a travel document. Clients without valid travel documents will not be permitted to travel.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by explaining that a stay permit and driving license do not qualify as valid travel documents for passengers. It clearly states the requirements for travel, making it relevant to the question asked.'}),
#  ({'doc_id': 7,
#    'chunk_id': 4,
#    'question': 'What is the consequence of not having a valid travel document?'},
#   'According to the provided context, the consequence of not having a valid travel document is that clients without valid travel documents will not be permitted to travel.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the consequence of not having a valid travel document by stating that clients without valid travel documents will not be permitted to travel, which is a clear and relevant consequence.'}),
#  ({'doc_id': 7,
#    'chunk_id': 4,
#    'question': 'What is the departure and arrival location for the mentioned travel route?'},
#   'According to the provided document, the travel route is from Berlin, ZOB am Funkturm to Prague, ÚAN Florenc. The departure time is 7th September 2024, 10:00 AM, and the arrival time is 7th September 2024, 12:30 PM.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by providing both the departure location (Berlin, ZOB am Funkturm) and the arrival location (Prague, ÚAN Florenc) for the travel route, along with the corresponding departure and arrival times.'}),
#  ({'doc_id': 7,
#    'chunk_id': 5,
#    'question': 'What are the maximum dimensions allowed for hand baggage?'},
#   'According to the document, the maximum dimensions allowed for hand baggage are:\n\n* 15x25x35 cm',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by providing the specific maximum dimensions allowed for hand baggage, which is exactly what was asked.'}),
#  ({'doc_id': 7,
#    'chunk_id': 5,
#    'question': 'What is the weight limit for the free checked baggage?'},
#   'According to the document, the weight limit for the free checked baggage is 30 kg with dimensions up to 30x60x80 cm in the baggage compartment.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by providing the specific weight limit for free checked baggage, which is 30 kg, and mentions the dimensions, adding useful context.'}),
#  ({'doc_id': 7,
#    'chunk_id': 5,
#    'question': 'How much does it cost to transport a bicycle if paid in advance through the booking system?'},
#   'According to the provided context, the cost to transport a bicycle if paid in advance through the booking system is EUR 6.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly provides the cost of transporting a bicycle when paid in advance, which is exactly what the question is asking for.'}),
#  ({'doc_id': 7,
#    'chunk_id': 5,
#    'question': 'What is the fee for oversized baggage if paid at the bus?'},
#   'According to the provided text, the fee for oversized baggage if paid at the bus is CZK 200/EUR 8/CHF 10/HUF 2400.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by providing the specific fee for oversized baggage when paid at the bus, including the amounts in different currencies.'}),
#  ({'doc_id': 7,
#    'chunk_id': 5,
#    'question': 'What is the location of departure and destination for this travel route?'},
#   'According to the provided context, the departure location is Berlin, ZOB (Zentraler Omnibusbahnhof) and the destination is Prague, ÚAN Florenc.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by providing specific locations for both the departure (Berlin, ZOB) and the destination (Prague, ÚAN Florenc), making it fully relevant to the inquiry about the travel route.'}),
#  ({'doc_id': 7,
#    'chunk_id': 6,
#    'question': 'What is the departure date for the travel?'},
#   'According to the provided context, the departure date for the travel is:\n\n* 30 November 2023 (for the flight from Berlin-Brandenburg (BER) to Tromso (TOS))',
#   {'Relevance': 'RELEVANT',
#    'Explanation': "The generated answer directly provides the requested departure date for the travel, which is clearly stated as '30 November 2023'. This information is relevant and answers the question accurately."}),
#  ({'doc_id': 7,
#    'chunk_id': 6,
#    'question': 'Which stations are involved in the travel?'},
#   'According to the provided document, the stations involved in the travel are:\n\n1. Prague, ÚAN Florenc (Departure)\n2. Berlin, ZOB am Funkturm (Arrival)\n\nThese two stations are mentioned in the "Station/Transfer" section of the document.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by explicitly listing the stations involved in the travel (Prague, ÚAN Florenc and Berlin, ZOB am Funkturm) and provides context by mentioning their roles as departure and arrival stations.'}),
#  ({'doc_id': 7, 'chunk_id': 6, 'question': 'What time does the travel begin?'},
#   'According to the provided document, the travel begins at 09:45 AM on November 30, 2023, at Berlin-Brandenburg (BER) Terminal 2.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by providing the specific time when the travel begins, along with additional relevant details such as the date and location.'}),
#  ({'doc_id': 7, 'chunk_id': 6, 'question': 'When does the travel end?'},
#   'According to the provided itinerary, the travel ends on September 7th, 2024, at 2:25 PM in Prag Busbahnhof (ÚAN Florenc).',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by providing a specific date and time when the travel ends, along with the location, which is exactly what was asked.'}),
#  ({'doc_id': 7,
#    'chunk_id': 6,
#    'question': 'What platform number is assigned for this trip?'},
#   'According to the provided context, the platform number is not mentioned. The context only provides information about the ticket, routes, and conditions, but it does not mention the platform number.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question about the platform number by stating that it is not mentioned in the provided context. This acknowledges the inquiry and clarifies the absence of information, making the response relevant to the question asked.'})]

# %%
df_eval = pd.DataFrame(evaluations, columns=['record', 'answer', 'evaluation'])
# df_eval['id'] = df_eval.record.apply(lambda d: d['id'])
df_eval['question'] = df_eval.record.apply(lambda d: d['question'])

df_eval['relevance'] = df_eval.evaluation.apply(lambda d: d['Relevance'])
df_eval['explanation'] = df_eval.evaluation.apply(lambda d: d['Explanation'])

# %%
df_eval.head()
# Out:
#                                               record  \
# 0  {'doc_id': 0, 'chunk_id': 0, 'question': 'What...
# 1  {'doc_id': 0, 'chunk_id': 0, 'question': 'How ...
# 2  {'doc_id': 0, 'chunk_id': 0, 'question': 'What...
# 3  {'doc_id': 0, 'chunk_id': 0, 'question': 'In w...
# 4  {'doc_id': 0, 'chunk_id': 0, 'question': 'What...
#
#                                               answer  \
# 0  According to the provided context, the date an...
# 1  Based on the provided context, the booking inc...
# 2  According to the provided context, the total p...
# 3  According to the provided context, the Aurora ...
# 4  According to the provided context, the duratio...
#
#                                           evaluation  \
# 0  {'Relevance': 'RELEVANT', 'Explanation': 'The ...
# 1  {'Relevance': 'RELEVANT', 'Explanation': 'The ...
# 2  {'Relevance': 'RELEVANT', 'Explanation': 'The ...
# 3  {'Relevance': 'RELEVANT', 'Explanation': 'The ...
# 4  {'Relevance': 'RELEVANT', 'Explanation': 'The ...
#
#                                             question relevance  \
# 0  What is the date and time of the Aurora Boreal...  RELEVANT
# 1       How many adults are included in the booking?  RELEVANT
# 2  What is the total price for the Aurora Boreali...  RELEVANT
# 3  In which language will the Aurora Borealis Tou...  RELEVANT
# 4  What is the duration of the Aurora Borealis Tour?  RELEVANT
#
#                                          explanation
# 0  The generated answer directly addresses the qu...
# 1  The generated answer directly addresses the qu...
# 2  The generated answer directly addresses the qu...
# 3  The generated answer directly addresses the qu...
# 4  The generated answer directly addresses the qu...

# %%
df_eval.relevance.value_counts(normalize=True)
# Out:
# relevance
# RELEVANT           0.965957
# PARTLY_RELEVANT    0.029787
# NON_RELEVANT       0.004255
# Name: proportion, dtype: float64
